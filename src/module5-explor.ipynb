# %% [markdown]
# # **Module 5 : Analyse exploratoire des données (EDA)**
# ---

# %% [markdown]
# ✅ Objectif : Extraire des insights des données.

# %% [markdown]
# ## **1 - Statistiques descriptives (`mean()`, `median()`, `std()`, `corr()`)**

# %% [markdown]
# ## **2 - Analyse des distributions et des outliers**

# %% [markdown]
# ## **3 - Matrices de corrélation et heatmaps**

# %% [markdown]
# ## **4 - Analyse des relations entre variables (catégoriques et numériques)**

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#
# File ~/micromamba/lib/python3.9/site-packages/pandas/__init__.py:49
#      46 # let init-time option registration happen
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#      52     Int8Dtype,
#      53     Int16Dtype,
#      54     Int32Dtype,
#      55     Int64Dtype,
#      56     UInt8Dtype,
#      57     UInt16Dtype,
#      58     UInt32Dtype,
#      59     UInt64Dtype,
#      60     Float32Dtype,
#      61     Float64Dtype,
#      62     CategoricalDtype,
#      63     PeriodDtype,
#      64     IntervalDtype,
#      65     DatetimeTZDtype,
#      66     StringDtype,
#      67     BooleanDtype,
#      68     # missing
#      69     NA,
# ...

# %%
import os
os.chdir("d:/Projet/formation")
import pandas as pd
data = pd.read_csv("data/raw/cs-training.csv").iloc[:, 1:]
data.to_csv('data/processed/cse_for_acp.csv', index=False, encoding='utf-8')
if input("y/n")=="y":
    import subprocess
    subprocess.run(["Rscript", "d:/Projet/formation/src/modules/cse_for_acp.R"], check=True)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/home/kamoussou/micromamba/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/kamoussou/micromamba/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/kamoussou/micromamba/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
# ...

# %%
import os
os.chdir("d:/Projet/formation")
import pandas as pd
data = pd.read_excel("data/raw/pays.xlsx")
data.to_csv('data/processed/pays_for_acp.csv', index=False, encoding='utf-8') 
if input("y/n")=="y":
    import subprocess
    subprocess.run(["Rscript", "d:/Projet/formation/src/modules/pays_for_acp.R"], check=True)

# %%
data
# Out:
#               Pays  GDP per capita, PPP (constant 2000 international $)   \
# 0          Albania                                        4506.060302
# 1          Algeria                                        6063.033154
# 2           Angola                                        1830.223475
# 3        Argentina                                       11778.072092
# 4          Armenia                                        3905.012077
# ..             ...                                                ...
# 136  Venezuela, RB                                        5376.612540
# 137        Vietnam                                        2557.832629
# 138    Yemen, Rep.                                         832.750992
# 139         Zambia                                         878.968439
# 140       Zimbabwe                                        1933.822443
#
#      GDP per capita growth (annual %)   \
# 0                             5.116763
# 1                             4.196593
# ...

# %%
data.set_index('Pays', inplace=True)
data['Continent'] = data['Continent'].astype('category')

# %%
data.columns
# Out:
# Index(['GDP per capita, PPP (constant 2000 international $) ',
#        'GDP per capita growth (annual %) ',
#        'Gross fixed capital formation (% of GDP) ',
#        'Agriculture value added per worker (constant 2000 US$) ',
#        'Agriculture, value added (% of GDP) ',
#        'Exports of goods and services (% of GDP) ',
#        'Foreign direct investment, net inflows (% of GDP) ',
#        'Improved water source (% of population with access) ',
#        'Industry, value added (% of GDP) ',
#        'Mobile phone subscribers (per 1,000 people) ',
#        'Mortality rate, infant (per 1,000 live births) ',
#        'Personal computers (per 1,000 people) ',
#        'Population ages 0-14 (% of total) ',
#        'Population ages 65 and above (% of total) ',
#        'Rural population (% of total population) ',
#        'Services, etc., value added (% of GDP) ',
#        'Population growth (annual %) ', 'Internet users (per 1,000 people) ',
#        'Continent'],
# ...

# %%
import os
os.chdir("d:/Projet/formation")
import pandas as pd
data = pd.read_excel("data/raw/pays.xlsx")
data.to_csv('data/processed/pays_for_acp.csv', index=False, encoding='utf-8')

# %%
from src.modules.plots import Plots
Plots(data).boxplot("Mobile phone subscribers (per 1,000 people) ", "Continent", (15, 8))
# Out:
# d:\Projet\formation\src\modules\plots.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.data, x=var_cat, y=var_quant, palette="Set2")

# %%
from src.modules.plots import Plots
Plots(data).scatter("Population ages 0-14 (% of total) ", "GDP per capita growth (annual %) ", "Continent", (15, 8))
